# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
class Percepetron():
    def __init__(self):
        self.weight = np.random.rand(1)
        self.weight_bias = np.random.rand(1)
    def fit(self, dataset_path):
        self.dataframe = pd.read_csv(dataset_path)
        self.columns = []

# %%
slp = Percepetron()
slp.fit('/home/gustavo/Downloads/ova.csv')
# Out:
# Choose features by name:
#  ['Weight', 'Size', 'Class']
